# %%
## import modules

# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load data

# %% [markdown]
# ###  true

# %%
fname = 'state_true.nc'
fh = Dataset(fname, mode='r')
hfilt = fh.variables['Hfil'][:,:,:]
uphyt = fh.variables['Uphy'][:,:,:]
vphyt = fh.variables['Vphy'][:,:,:]

fh.close()
t=1000
plt.imshow(hfilt[t,:,:])
plt.gca().invert_yaxis()
plt.show()

# %%
fname = 'state_a.nc'
fh = Dataset(fname, mode='r')
hfila = fh.variables['Hfil'][:,:,:]
uphya = fh.variables['Uphy'][:,:,:]
vphya = fh.variables['Vphy'][:,:,:]
fh.close()
t=2
plt.imshow(hfila[t,:,:])
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### balanced

# %%
fname = 'state_balanced.nc'
fh = Dataset(fname, mode='r')
hfilb = fh.variables['Hfil'][:,:,:]
fh.close()
t=1000
plt.imshow(hfilb[t,:,:])
plt.gca().invert_yaxis()
plt.show()

# %%
fname = 'state_balanced.nc'
fh = Dataset(fname, mode='r')
uphyb = fh.variables['Uphy'][:,:,:]
fh.close()
t=1
plt.imshow(uphyb[t,:,:])
plt.colorbar()
plt.show()

uphyb[t,0,-3]

# %% [markdown]
# ###  lin

# %%
fname = 'state_true_lin.nc'
fh = Dataset(fname, mode='r')
hfill = fh.variables['Hfil'][:,:,:]
print hfill.shape
fh.close()

# %% [markdown]
# ###  linearization point

# %%
fname = 'state_0.nc'
fh = Dataset(fname, mode='r')
hfil0 = fh.variables['Hfil'][:,:,:]
print hfil0.shape
fh.close()

# %% [markdown]
# ###  4dvar

# %%
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print "Current size:", fig_size
 
# Set figure width to 12 and height to 9
fig_size[0] = 18
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

print "New size:", fig_size
# Out:
# Current size: [6.0, 4.0]
# New size: [18, 9]

# %%
nfig =3
t=1000
im=range(0,nfig)
fig, ax = plt.subplots(ncols=nfig)
im[0] = ax[0].imshow(hfilt[t,:,:])
im[1] = ax[1].imshow(hfill[t,:,:])
im[2] = ax[2].imshow(hfill[t,:,:]-hfilt[t,:,:])
plt.subplots_adjust(bottom=0.2)
for k in range(0,len(im)):
    pos = ax[k].get_position()
    cbar_ax = fig.add_axes([pos.x0, 0.15, pos.width, 0.05])
    plt.colorbar(im[k],orientation='horizontal',cax=cbar_ax)

plt.show()

# %%
nfig =3
t=1
im=range(0,nfig)
fig, ax = plt.subplots(ncols=nfig)
im[0] = ax[0].imshow(hfilt[t,:,:])
im[1] = ax[1].imshow(hfila[t,:,:])
im[2] = ax[2].imshow(hfila[t,:,:]-hfilt[t,:,:])
plt.subplots_adjust(bottom=0.2)
for k in range(0,len(im)):
    pos = ax[k].get_position()
    cbar_ax = fig.add_axes([pos.x0, 0.15, pos.width, 0.05])
    plt.colorbar(im[k],orientation='horizontal',cax=cbar_ax)

plt.show()

# %%
plt.plot(hfilt[0,:,0])
plt.plot(hfila[0,:,0])
plt.show()
print hfilt[0,10,0]
# Out:
# 49.253163513

# %%
nfig =3
t=3
im=range(0,nfig)
fig, ax = plt.subplots(ncols=nfig)
im[0] = ax[0].imshow(hfilt[t,:,:])
im[1] = ax[1].imshow(hfil0[t,:,:])
im[2] = ax[2].imshow(hfil0[t,:,:]-hfilt[t,:,:])
plt.subplots_adjust(bottom=0.2)
for k in range(0,len(im)):
    pos = ax[k].get_position()
    cbar_ax = fig.add_axes([pos.x0, 0.15, pos.width, 0.05])
    plt.colorbar(im[k],orientation='horizontal',cax=cbar_ax)

plt.show()

# %%
t = range(0,hfilt.shape[0])
x=10
y=40
plt.plot(t,hfilt[:,x,y],color='red')
plt.plot(t,hfill[:,x,y],color='blue')
plt.show()

# %% [markdown]
# ## Init des termes (balanced) de vitesse

# %%
# %%latex
# En négligeant les termes non linéaires et diffusion, on a un etat stationnaire vérifiant :
# \begin{eqnarray}
#     f.v -  \partial_x g^*.h + \frac{\tau_x}{\rho_0h} - \gamma.u & = & 0 \nonumber \\
#     -f.u - \partial_y g^*.h + \frac{\tau_y}{\rho_0h} - \gamma.v & = & 0 \nonumber
# \end{eqnarray}
#
# Dans un premier temps, on néglige aussi la dissipation :
# \begin{eqnarray}
#     v & = &  \frac{-\tau_x}{f.\rho_0h} + \frac{g^*}{f}\partial_x h \nonumber \\
#     u & = & \frac{\tau_y}{f.\rho_0h} - \frac{g^*}{f}\partial_y h \nonumber
# \end{eqnarray}

# %%
nfig =3
t=1000
im=range(0,nfig)
fig, ax = plt.subplots(ncols=nfig)
im[0] = ax[0].imshow(hfilt[t,:,:])
im[1] = ax[1].imshow(hfilb[t,:,:])
im[2] = ax[2].imshow(hfilb[t,:,:]-hfilt[t,:,:])
plt.subplots_adjust(bottom=0.2)
for k in range(0,len(im)):
    pos = ax[k].get_position()
    cbar_ax = fig.add_axes([pos.x0, 0.15, pos.width, 0.05])
    plt.colorbar(im[k],orientation='horizontal',cax=cbar_ax)

plt.show()

# %%
for i in range(50):print(i)

# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button, RadioButtons

fig, ax = plt.subplots()

#size of the window :
plt.subplots_adjust(left=0.25, bottom=0.25)


t = np.arange(0.0, 1.0, 0.001)
a0 = 5
f0 = 3
s = a0*np.sin(2*np.pi*f0*t)
l, = plt.plot(t, s, lw=2, color='red')
plt.axis([0, 1, -10, 10])

axcolor = 'lightgoldenrodyellow'

#axes ([left bottom width heigth])
axfreq = plt.axes([0.25, 0.1, 0.65, 0.03], axisbg=axcolor)
axamp = plt.axes([0.25, 0.15, 0.65, 0.03], axisbg=axcolor)

sfreq = Slider(axfreq, 'Freq', 0.1, 30.0, valinit=f0)
samp = Slider(axamp, 'Amp', 0.1, 10.0, valinit=a0)


def update(val):
    amp = samp.val
    freq = sfreq.val
    l.set_ydata(amp*np.sin(2*np.pi*freq*t))
    fig.canvas.draw_idle()
sfreq.on_changed(update)
samp.on_changed(update)

resetax = plt.axes([0.8, 0.025, 0.1, 0.04])
button = Button(resetax, 'Reset', color=axcolor, hovercolor='0.975')


def reset(event):
    sfreq.reset()
    samp.reset()
button.on_clicked(reset)

rax = plt.axes([0.025, 0.5, 0.15, 0.15], axisbg=axcolor)
radio = RadioButtons(rax, ('red', 'blue', 'green'), active=0,activecolor='black')


def colorfunc(label):
    l.set_color(label)
    fig.canvas.draw_idle()
radio.on_clicked(colorfunc)

plt.show()
